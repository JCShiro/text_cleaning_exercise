# %% [markdown]
# # Python Worksheet for text cleaning
#
# ## Objectives
#
# - Reading from a file and writing to a new file
# - Clean and preprocess raw text data (from the text file provided)
# - Apply regular expressions for text filtering
# - Remove stopwords and punctuation
# - Perform frequency and term analysis
# - Generate word clouds
# - Extract insights from textual data

# %% [markdown]
# # Overall Task
#
# Using the Lord of the Rings text file provided, install the packages mentioned at the top of the program, then go through each step of the text cleaning process to then output the cleaned text in a new text file, and create a word cloud of the most frequently used terms. If you get stuck you can always use google and Stack Overflow for hints and help.

# %% [markdown]
# # Install packages

# %%
import re
import nltk
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from collections import Counter
from nltk.util import bigrams

nltk.download('punkt_tab')
nltk.download('stopwords')

# %%
# Add your code here for reading the text file and print out the first 500 characters

# %%
# Add code here for printing the Character Count and Word count of the text file

# %%
# Add code here to take the text and covert it all to lower case, and print out the first 500 characters again

# %%
# Add code here for Regular Expression to remove punctuation and numbers and then print the text to see how it's changed

# %%
# Tokenize the new text and print out the first 50 tokens

# %%
# Using this code, remove the stopwords from the text (optional remove words that are 2 or less.)

stop_words = set(stopwords.words('english'))

# %%
# Now output the newly cleaned text into a new text file

# %%
# Using the Pandas package, create a graph to display the word frequency for the 10 most frequent terms in the file

# %%
# Using the wordcloud package, create a wordcloud for the most commonly used words in the text

# %%
# Extra task - experiment with stemming words and see how it can change the data, are some stemmers more aggressive than others?

# %%
# Extra task - using bigrams, work out the Lexical Diversity
